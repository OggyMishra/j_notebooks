# %%
import pandas as pd
df = pd.read_csv('Noida2.csv', encoding='unicode_escape')
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header 
columns = list(df.columns)
columns = [x for x in columns if str(x) != 'nan' and str(x) != 'Correct Answers']
columns
for col in columns:
    df[col] = df[col] == col
df.head() 
df['Correct Answer'] = (df == True).sum(axis =1)
df.to_csv('result.csv')

# %%
# Out:
# 0                  NaN                               NaN  Jai Prakash  \
# 1  11/14/2019 15:20:51  sukriti.kukrety@visiblealpha.com        False
# 2  11/14/2019 15:20:51    himanshu.jain@visiblealpha.com        False
# 3  11/14/2019 15:24:12  parnika.agarwal@visiblealpha.com        False
# 4  11/14/2019 15:25:33   rachita.rajput@visiblealpha.com        False
#
# 0  Parnika  Divya Goel  Akshay saxena  Manav Gogia  Garima Jain  \
# 1     True       False           True        False        False
# 2     True       False          False        False        False
# 3    False       False          False        False         True
# 4     True       False          False        False         True
#
# 0  Rishabh Mendiratta  Ankur Jindal  ...  Sahil Gupta  Vasudha Chopra  \
# 1               False         False  ...         True           False
# 2               False         False  ...         True           False
# 3               False         False  ...         True           False
# ...
