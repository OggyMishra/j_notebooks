# %%
import requests
import json
import io
import pandas as pd
api = 'https://app.visiblealpha.com/api/'
resource = 'addinpg?ticker=FLR&cut=SD&pg=OP&period=FY-2018&clienttype=addin,v0.9.17001.0'
token = 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiI0NDI0Nn5-MjAxOS0wMy0yMX5-MTU1OTU2OTYyNi4wIiwiYXBwIjoiYWRkaW4iLCJ1c2VyIjoic291cmFiaC5taXNocmFAdmlzaWJsZWFscGhhLmNvbSIsImV4cCI6MTU5MTA5MTIyNi4wfQ.PjBeIFS1tjk3HeL7r9inSIu4lUFBvdM5rz_LBM2qLhk7zySAagbRrBnQED9Hb0e2pxFA1x7r33dcjob5xrI6ncLMB9vpZ3ohB6e6tGUPM1Jagvh5JyrfLv-1Pkg4OuysIDh1vbkPRWIpLbBwTqga5eGGTBX7qIUsiJQi_o5e_DGFoP4-cLDeKk_Ih1UU-CmYas0cewZO_EsHjnZtt2gIS1oI-7o6RqHxlfStYu-ONBfgpC3WhoYEJmGZ1ldWTbaTGYTJc9geHyErtp3bvt3scbKnNm1H9raY158kWRsfDt9bEEZ-dYDLHWWfFeJH39iJMDlmrEAs1vzy4sFNRRcqHg'
data = requests.get(api+ resource, headers={'Authorization': token}).content
jsonObj = json.loads(data.decode('utf-8'))

periods = []
values = []
parameterIds = []
paramIds = []
precisions = []
ids = []
annotations = []
units = []

ticker = jsonObj['data'][0]['ticker']

for d in jsonObj['data'][0]['data']:
    periods.append(d[u'period'])
    values.append(d[u'value'])
    parameterIds.append(d[u'parameterid'])
    paramIds.append(d[u'param_id'])
    precisions.append(d[u'precision'])
    ids.append(d[u'id'])
    annotations.append(d[u'annotation'])
    units.append(d[u'unit'])
    
    
df = pd.DataFrame( {'ticker': ticker, 'Periods': periods,'Values': values, 'ParameterIds': parameterIds, 
                  'ParamIds': paramIds, 'Precisions': precisions, 'Ids': ids, 'Annotations': annotations,
                  'Units':units })
df.r
df
# Out:
#     ticker  Periods          Values  ParameterIds  ParamIds  Precisions  \
# 0      FLR  FY-2018  -12.3495105594        211662    211662           2
# 1      FLR  FY-2018    -12.07193592        211662    211662           2
# 2      FLR  FY-2018    -12.07193592        211662    211662           2
# 3      FLR  FY-2018   -1.8884438655        212133    212133           2
# 4      FLR  FY-2018  -1.88845901214        212133    212133           2
# 5      FLR  FY-2018  -1.88845901214        212133    212133           2
# 6      FLR  FY-2018      15112.9922        217195    217195           2
# 7      FLR  FY-2018      15112.9935        217195    217195           2
# 8      FLR  FY-2018      15112.9935        217195    217195           2
# 9      FLR  FY-2018          4586.0        217197    217197           2
# 10     FLR  FY-2018          4586.0        217197    217197           2
# 11     FLR  FY-2018          4586.0        217197    217197           2
# ...

# %%
import requests
import json
import pandas as pd
api = 'https://app.visiblealpha.com/addin/get_comps_data_addin'
payload = {"t":["USCR_US"], "l":["Total Revenue"], "lid":[], "s":["Consensus"], "p":["FY-2018"], "r":["Current"], "g":[], "d":["implied"]}
token = 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiI0M35-MjAxOS0wNy0yMn5-MTU3MDc4Nzg5My4wIiwiYXBwIjoiYWRkaW4iLCJ1c2VyIjoicGl5dXNoLnBhbmthakB2aXNpYmxlYWxwaGEuY29tIiwiZXhwIjoxNjAyMzA5NDkzLjB9.MDrEqLOwb2_ST0m-vK6kxLY8liMbYPk2R8jcOs_24_FL1fCFFIBXoVBbiSxS3HV1v7wLO8PAdFLVCA-ZPUlEz-z99g9in3yaLTZGOXmcsEE9dKpmT3A50pKmTO6F4kaJppsUr-TlCO2B1HicX-prd9F-DZAqD9OZhfoixvVX9sMOYdi8AIFC4WBgnDDs8rudcInLWRPcDT_89p6EXEVKK53MThHqlRU6SZ1xZhICnf9T4unK7CnMUuqsuFld_erBNXY4bxZV_OikdnrxQq-XebQmA9slRZn7F5uYB5ZtPGhv2D5txXsDy4-GFoGiILm5Qig0t_1lHbitir-N-460hA'
res = requests.post(api, data = payload, headers={'Authorization': token, 'content-type': 'application/json'}).content
#print(res.content)
aps = res.decode('utf-8')
print(aps)

# %%
input = '{"t":["USCR_US"],"l":["Total Revenue"],"lid":[],"s":["Consensus"],"p":["FY-2018"],"r":["Current"],"g":[],"d":["implied"]}'
#res  = json.dumps(input)
res = requests.post(api, data = json.dumps(input), headers={'Authorization': token, 'content_type': 'application/json'}).content
print(res)
# Out:
# b'{"status":"error","message":"\'unicode\' object has no attribute \'get\'"}'

# %%
url = "https://app.visiblealpha.com/addin/get_comps_data_addin"
payload = {
    t:["USCR_US"],
    l:["Total Revenue"],
    lid:[],
    s:["Consensus"],
    p:["FY-2018"],
    r:["Current"],
    g:[],
    d:["implied"]
}
headers = {
    'Authorization': "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiI0NDI0Nn5-MjAxOS0wMy0yMX5-MTU1OTU2OTYyNi4wIiwiYXBwIjoiYWRkaW4iLCJ1c2VyIjoic291cmFiaC5taXNocmFAdmlzaWJsZWFscGhhLmNvbSIsImV4cCI6MTU5MTA5MTIyNi4wfQ.PjBeIFS1tjk3HeL7r9inSIu4lUFBvdM5rz_LBM2qLhk7zySAagbRrBnQED9Hb0e2pxFA1x7r33dcjob5xrI6ncLMB9vpZ3ohB6e6tGUPM1Jagvh5JyrfLv-1Pkg4OuysIDh1vbkPRWIpLbBwTqga5eGGTBX7qIUsiJQi_o5e_DGFoP4-cLDeKk_Ih1UU-CmYas0cewZO_EsHjnZtt2gIS1oI-7o6RqHxlfStYu-ONBfgpC3WhoYEJmGZ1ldWTbaTGYTJc9geHyErtp3bvt3scbKnNm1H9raY158kWRsfDt9bEEZ-dYDLHWWfFeJH39iJMDlmrEAs1vzy4sFNRRcqHg"
    }

response = requests.request("POST", url, data=payload, headers=headers)
print(response)
